# %% [markdown]
# ## Building a RAG Helper Class

# %%
from dotenv import load_dotenv
load_dotenv()

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI

# %%
documents = load_faq_data()
index = build_index(documents) # ingest.py uses minsearch

openai_client = OpenAI()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can still join now. If you want a certificate, make sure to submit your project while submissions are still open.

# %% [markdown]
# #### Overriding the class

# %%
custom_instructions = """
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
    instructions=custom_instructions,
)

# %%
assistant.rag("How do I get a certificate?")
assistant.rag("Can I still join the course after it started?")
# Out:
# 'Yes, you can join even after the course has started. If you want a certificate, though, you need to finish the course with a live cohort and submit your project while submissions are still being accepted.'

# %%
assistant.rag("how do I run Olama locally?")
# Out:
# 'I don’t see any FAQ entry for “Olama,” but if you mean running the course locally, the FAQ says you can do that if you’re comfortable setting up the needed tools yourself.\n\nYou’d need to set up:\n- Python\n- `uv`\n- Jupyter\n- Docker\n- any other tools needed for the module\n\nAlso, if you run locally, make sure to:\n- document your setup\n- keep your environment reproducible\n\nIf you meant a specific tool other than “Olama,” tell me the name and I’ll help based on the FAQ.'
